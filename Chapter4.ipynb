# %% [markdown]
# Compare

# %%
weight = 0.5
input = 0.5
goal = 0.8

prediction = weight * input

error = (goal - prediction) ** 2

print(error)
# Out:
# 0.30250000000000005

# %% [markdown]
# Simple gradient descent

# %%
weight = 0.5
goal_pred = 0.8
input = 2
alpha = 0.1

for i in range(20):
  prediction = input * weight
  error = (prediction - goal_pred)**2
  delta = prediction - goal_pred
  delta_weight = input * (prediction - goal_pred)
  weight = weight - (delta_weight * alpha)
print(prediction)
# Out:
# 0.8000121871948003
