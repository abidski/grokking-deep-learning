# %%
import sys,numpy as np
from keras.datasets import mnist

(x_train,y_train), (x_test,y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000,28*28)/255,y_train[0:1000])

one_hot_labels = np.zeros((len(labels),10))

for i,l in enumerate(labels):
  one_hot_labels[i][l] = 1
labels= one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) /255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
  test_labels[i][l]=1

np.random.seed(1)
relu = lambda x: (x>=0)*x
relu2deriv = lambda x : x>=0

alpha,iterations,hidden_size,pixels_per_image, num_labels = (0.005, 350,40,784,10)
weights_0_1 = 0.2 * np.random.random((pixels_per_image,hidden_size))-0.1
weights_1_2 = 0.2 * np.random.random((hidden_size,num_labels))-0.1

for j in range(iterations):
  error,correct_cnt = (0.0, 0)
  for i in range(len(images)):
    layer_0 = images[i:i+1]
    layer_1 = relu(layer_0.dot(weights_0_1))
    layer_2 = layer_1.dot(weights_1_2)
    error += np.sum((layer_2 - labels[i])**2)
    correct_cnt += int(np.argmax(layer_2) == np.argmax(labels[i:i+1]))

    layer_2_delta = labels[i:i+1]-layer_2
    layer_1_delta = layer_2_delta.dot(weights_1_2.T) * relu2deriv(layer_1)


    weights_1_2 += alpha * layer_1.T.dot(layer_2_delta)
    weights_0_1 += alpha * layer_0.T.dot(layer_1_delta)
  sys.stdout.write("\r"+ \
" I:"+str(j)+ \
" Error:" + str(error/float(len(images)))[0:5] +\
" Correct:" + str(correct_cnt/float(len(images))))
# Out:
#  I:349 Error:0.108 Correct:1.0

# %%
if(j % 10 == 0 or j == iterations-1):
    error, correct_cnt = (0.0, 0)

    for i in range(len(test_images)):

        layer_0 = test_images[i:i+1]
        layer_1 = relu(np.dot(layer_0,weights_0_1))
        layer_2 = np.dot(layer_1,weights_1_2)

        error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
        correct_cnt += int(np.argmax(layer_2) == \
                                        np.argmax(test_labels[i:i+1]))
    sys.stdout.write(" Test-Err:" + str(error/float(len(test_images)))[0:5] +\
                     " Test-Acc:" + str(correct_cnt/float(len(test_images))) + "\n")
    print()
# Out:
#  Test-Err:0.653 Test-Acc:0.7073

# %%
import sys, numpy as np
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

images, labels = (x_train[0:1000].reshape(1000,28*28) / 255, y_train[0:1000])

one_hot_labels = np.zeros((len(labels),10))
for i,l in enumerate(labels):
    one_hot_labels[i][l] = 1
labels = one_hot_labels

test_images = x_test.reshape(len(x_test),28*28) / 255
test_labels = np.zeros((len(y_test),10))
for i,l in enumerate(y_test):
    test_labels[i][l] = 1

np.random.seed(1)
relu = lambda x:(x>=0) * x # returns x if x > 0, return 0 otherwise
relu2deriv = lambda x: x>=0 # returns 1 for input > 0, return 0 otherwise
alpha, iterations, hidden_size, pixels_per_image, num_labels = (0.005, 350, 40, 784, 10)

np.random.seed(1)

def relu(x):
    return (x >= 0) * x # returns x if x > 0

def relu2deriv(output):
    return output >= 0 # returns 1 for input > 0

batch_size = 100
alpha, iterations = (0.001, 300)
pixels_per_image, num_labels, hidden_size = (784, 10, 100)

weights_0_1 = 0.2*np.random.random((pixels_per_image,hidden_size)) - 0.1
weights_1_2 = 0.2*np.random.random((hidden_size,num_labels)) - 0.1


for j in range(iterations):
    error, correct_cnt = (0.0, 0)
    for i in range(int(len(images)/batch_size)):


      beginning = i * batch_size
      end = (i+ 1)* batch_size
      layer_0 = images[beginning:end+1]
      layer_1 = relu(layer_0.dot(weights_0_1))
      dropout_mask = np.random.randint(2,size=layer_1.shape)
      layer_1 *= dropout_mask * 2
      layer_2 = layer_1.dot(weights_1_2)

      for k in range(batch_size):
        correct_cnt += int(np.argmax(layer_2[k:k+1]) == np.argmax(labels[(beginning+k):beginning+(k+1)]))
      delta_2 = layer_2 - labels[beginning:end+1]/batch_size
      delta_1 = (delta_2.dot(weights_1_2.T)*relu2deriv(layer_1))* dropout_mask
      weights_1_2 -= layer_1.T.dot(delta_2)* alpha
      weights_0_1 -= layer_0.T.dot(delta_1)* alpha
    if(j%10 == 0):
        test_error = 0.0
        test_correct_cnt = 0

        for i in range(len(test_images)):
            layer_0 = test_images[i:i+1]
            layer_1 = relu(np.dot(layer_0,weights_0_1))
            layer_2 = np.dot(layer_1, weights_1_2)

            test_error += np.sum((test_labels[i:i+1] - layer_2) ** 2)
            test_correct_cnt += int(np.argmax(layer_2) == np.argmax(test_labels[i:i+1]))

        sys.stdout.write("\n" + \
                         "I:" + str(j) + \
                         " Test-Err:" + str(test_error/ float(len(test_images)))[0:5] +\
                         " Test-Acc:" + str(test_correct_cnt/ float(len(test_images)))+\
                         " Train-Err:" + str(error/ float(len(images)))[0:5] +\
                         " Train-Acc:" + str(correct_cnt/ float(len(images))))
# Out:
# I:0 Test-Err:1.074 Test-Acc:0.1058 Train-Err:0.0 Train-Acc:0.084
# I:10 Test-Err:1.000 Test-Acc:0.1304 Train-Err:0.0 Train-Acc:0.099
# I:20 Test-Err:0.995 Test-Acc:0.148 Train-Err:0.0 Train-Acc:0.136
# I:30 Test-Err:0.995 Test-Acc:0.1563 Train-Err:0.0 Train-Acc:0.134
# I:40 Test-Err:0.994 Test-Acc:0.1682 Train-Err:0.0 Train-Acc:0.149
# I:50 Test-Err:0.993 Test-Acc:0.1826 Train-Err:0.0 Train-Acc:0.16
# I:60 Test-Err:0.992 Test-Acc:0.2119 Train-Err:0.0 Train-Acc:0.18
# I:70 Test-Err:0.993 Test-Acc:0.2139 Train-Err:0.0 Train-Acc:0.181
# I:80 Test-Err:0.993 Test-Acc:0.235 Train-Err:0.0 Train-Acc:0.204
# I:90 Test-Err:0.993 Test-Acc:0.2614 Train-Err:0.0 Train-Acc:0.228
# I:100 Test-Err:0.993 Test-Acc:0.2766 Train-Err:0.0 Train-Acc:0.249
# I:110 Test-Err:0.993 Test-Acc:0.2883 Train-Err:0.0 Train-Acc:0.244
# I:120 Test-Err:0.993 Test-Acc:0.3032 Train-Err:0.0 Train-Acc:0.278
# I:130 Test-Err:0.993 Test-Acc:0.3081 Train-Err:0.0 Train-Acc:0.286
# I:140 Test-Err:0.993 Test-Acc:0.3241 Train-Err:0.0 Train-Acc:0.266
# I:150 Test-Err:0.993 Test-Acc:0.3324 Train-Err:0.0 Train-Acc:0.296
# I:160 Test-Err:0.993 Test-Acc:0.3432 Train-Err:0.0 Train-Acc:0.298
# I:170 Test-Err:0.993 Test-Acc:0.3567 Train-Err:0.0 Train-Acc:0.299
# I:180 Test-Err:0.993 Test-Acc:0.3595 Train-Err:0.0 Train-Acc:0.313
# I:190 Test-Err:0.993 Test-Acc:0.3659 Train-Err:0.0 Train-Acc:0.342
# I:200 Test-Err:0.993 Test-Acc:0.3891 Train-Err:0.0 Train-Acc:0.358
# I:210 Test-Err:0.993 Test-Acc:0.3925 Train-Err:0.0 Train-Acc:0.366
# I:220 Test-Err:0.993 Test-Acc:0.4004 Train-Err:0.0 Train-Acc:0.362
# I:230 Test-Err:0.993 Test-Acc:0.3994 Train-Err:0.0 Train-Acc:0.364
# I:240 Test-Err:0.993 Test-Acc:0.4084 Train-Err:0.0 Train-Acc:0.387
# I:250 Test-Err:0.993 Test-Acc:0.4211 Train-Err:0.0 Train-Acc:0.368
# I:260 Test-Err:0.993 Test-Acc:0.4293 Train-Err:0.0 Train-Acc:0.379
# I:270 Test-Err:0.993 Test-Acc:0.4299 Train-Err:0.0 Train-Acc:0.39
# I:280 Test-Err:0.993 Test-Acc:0.4358 Train-Err:0.0 Train-Acc:0.406
# I:290 Test-Err:0.993 Test-Acc:0.4414 Train-Err:0.0 Train-Acc:0.416
